# %%
#Installing dependencies
# %pip install streamlit
# Out:
# ...
#   Using cached pillow-11.3.0-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/10.1 MB 7.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.9/10.1 MB 7.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.5/10.1 MB 7.5 MB/s eta 0:00:01
#    --------------------- ------------------ 5.5/10.1 MB 7.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/10.1 MB 7.1 MB/s eta 0:00:01
#    --------------------------------- ------ 8.4/10.1 MB 7.1 MB/s eta 0:00:01
#    -------------------------------------- - 9.7/10.1 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 10.1/10.1 MB 7.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
# ...

# %%
# Running an application:
# %streamlit run main.py
# Out:
# UsageError: Line magic function `%streamlit` not found.
